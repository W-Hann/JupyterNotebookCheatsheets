# %% [markdown]
# # Matplotlib Cheat Sheet

# %% [markdown]
# ### General Concepts
# A Matplotlib figure can be categorized into several parts as below:
#
# Figure: It is a whole figure which may contain one or more than one axes (plots). You can think of a Figure as a canvas which contains plots.
#
# Axes: It is what we generally think of as a plot. A Figure can contain many Axes. It contains two or three (in the case of 3D)       Axis objects. Each Axes has a title, an x-label and a y-label.
#
# Axis: They are the number line like objects and take care of generating the graph limits.
#
# Artist: Everything which one can see on the figure is an artist like Text objects, Line2D objects, collection objects. Most Artists are tied to Axes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# creating a basic plot

plt.figure(figsize=(10,5))          #setting plot size
plt.plot([1,2,3,4],[1,4,9,16],'g')  # data and colour (g)
plt.title("Generic Plot")           # title
plt.xlabel("X Label")               # x axis label
plt.ylabel("Y Label")               # y axis label

plt.show()                          # shows plot w/o output

# %%
# can plot 2 datasets in one graph like so

plt.figure(figsize=(10,5))          
plt.plot([1,2,3,4],[1,4,9,16],'go',np.arange(1,5),np.arange(1,5)**3,'r^') # plt.plot([x1],[y1],format,[x2].[y2],format)
plt.title("Generic Plot")           
plt.xlabel("X Label")              
plt.ylabel("Y Label")              

plt.show()

# %% [markdown]
# ### Using Subplots

# %% [markdown]
# use subplot to add more that 1 graph
#
# The subplot() method takes three arguments: they are nrows, ncols and index. They indicate the number of rows, number of columns and the index number of the sub-plot.
#
# If we want to create two sub-plots in one figure such that it comes in one row and in two columns, we pass arguments (1,2,1) and (1,2,2) in the subplot() method

# %%
# creating 2 plots separately
# play with the subplot indexing to see the effect (x,y,index)

plt.subplot(1,2,1)
plt.plot([1,2,3,4],[1,4,9,16],'go')
plt.title("Generic Graph 1")

plt.subplot(1,2,2)
plt.plot(np.arange(1,5),np.arange(1,5)**3,'r^')
plt.title("Generic Graph 2")

plt.suptitle("Graphs")         # suptitle() used for overall title
plt.show()

# %% [markdown]
# #### Above method can be tedious, use subplots() for many graphs

# %% [markdown]
# This method takes two arguments nrows and ncols as number of rows and number of columns respectively. This method creates two objects:figure and axes which we store in variables fig and ax which can be used to change the figure and axes level attributes respectively. Note that these variable names are chosen arbitrarily

# %%
# Essentially creates a blueprint/framework to fill with out data

fig, ax = plt.subplots(3,2,figsize=(10,10))  # 3,2 is rows, columns respectively

ax[0,1].plot([1,2,3,4],[1,4,9,16],'go')
ax[0,1].set_title("Generic Graph 1")

ax[2,0].plot(np.arange(1,5),np.arange(1,5)**3,'r^')
ax[2,0].set_title("Generic Graph 2")

plt.show()

# %% [markdown]
# ## Creating different types of Graphs

# %% [markdown]
# #### Bar graphs

# %%
x = ['A','B','C','D','E']
y = [10, 12, 14, 9, 8]
y_2 = [12, 11, 10, 9, 8]
variance = 2

# %%
# can use title, xlabel, ylabel as before

plt.bar(x,y,color='green')

plt.show()

# %%
plt.barh(x,y,xerr=variance,color='red')

plt.show()

# %%
# Creating a side-by-side bar needs a numeric x axis
# can then re-label the x axis using the xticks method

x_axis = np.arange(5)
width = 0.30

plt.bar(x_axis, y, width, color='green', label='Dataset 1')
plt.bar(x_axis+width, y_2, width, color='blue', label='Dataset 2')

plt.xticks(x_axis+width/2, x)   # centres the tick marks, and relabels using x variable defined at the start
plt.legend(loc='best')          # adds legend using 'label'
plt.show()

# %%
# creating a stacked bar graph uses bottom=variable to show which goes below

x_axis = np.arange(5)
width = 0.30

plt.bar(x_axis, y, width, color='green', label='Dataset 1')
plt.bar(x_axis, y_2, width, color='blue', label='Dataset 2', bottom=y)  # note added bottom, and removed x offset

plt.xticks(x_axis+width/2, x)   # centres the tick marks, and relabels using x variable defined at the start
plt.legend(loc='best')          # adds legend using 'label'
plt.show()

# %% [markdown]
# #### Pie Charts

# %%
Class = ['A','B','C','D','E']
Average_grade = [10, 12, 14, 9, 8]

# %%
# basic pie chart with essentials needed

plt.pie(Average_grade, labels=Class)
plt.axis('equal')
plt.legend(title='Classes')

plt.show()

# %%
# 'Advanced' pie chart with extra details

plt.pie(Average_grade, explode=[0,0.2,0,0,0], labels=Class, shadow=True, startangle=45)
plt.axis('equal')
plt.legend(title='Classes')

plt.show()

# %% [markdown]
# #### Histograms

# %%
random_data = np.random.randn(1000)

# %%
plt.hist(random_data,10)  # the 10 sets the number of bins. See below for the difference

plt.show()

# %%
plt.hist(random_data,50)

plt.show()

# %% [markdown]
# #### Scatter plots

# %%
height = [167,170,149,165,155,180,166,146,159,185,145,168,172,181,169]
weight = [86,74,66,78,68,79,90,73,70,88,66,84,67,84,77]

# %%
# plotting the basic scatter

plt.scatter(height,weight)

plt.show()

# %%
# plotting scatter where we set the x and y axis

plt.xlim(140,200)
plt.ylim(60,100)
plt.scatter(height,weight)

plt.show()

# %% [markdown]
# #### 3D Scatter Plots

# %%
from mpl_toolkits import mplot3d

# %% [markdown]
# A three-dimensional axes is created by passing the keyword projection='3d' to the axes() method of Pyplot module. Once the object instance is created, we pass our arguments height and weight to scatter3D() method.

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(height,weight)

ax.set_xlabel("Height")
ax.set_ylabel("Weight")

plt.show()

# %%
# 3D line plot
# Not very useful here, but could have interesting uses for the right data

ax = plt.axes(projection='3d')
ax.plot3D(height,weight)

ax.set_xlabel("Height")
ax.set_ylabel("Weight")

plt.show()

# %% [markdown]
# # Summary & Syntax

# %% [markdown]
# plot(x-axis values, y-axis values) — plots a simple line graph with x-axis values against y-axis values
#
# show() — displays the graph
#
# title(“string”) — set the title of the plot as specified by the string
#
# xlabel(“string”) — set the label for x-axis as specified by the string
#
# ylabel(“string”) — set the label for y-axis as specified by the string
#
# figure() — used to control a figure level attributes
#
# subplot(nrows, ncols, index) — Add a subplot to the current figure
#
# suptitle(“string”) — It adds a common title to the figure specified by the string
#
# subplots(nrows, ncols, figsize) — a convenient way to create subplots, in a single call. It returns a tuple of a figure and number of axes.
#
# set_title(“string”) — an axes level method used to set the title of subplots in a figure
#
# bar(categorical variables, values, color) — used to create vertical bar graphs
#
# barh(categorical variables, values, color) — used to create horizontal bar graphs
#
# legend(loc) — used to make legend of the graph
#
# xticks(index, categorical variables) — Get or set the current tick locations and labels of the x-axis
#
# pie(value, categorical variables) — used to create a pie chart
#
# hist(values, number of bins) — used to create a histogram
#
# xlim(start value, end value) — used to set the limit of values of the x-axis
#
# ylim(start value, end value) — used to set the limit of values of the y-axis
#
# scatter(x-axis values, y-axis values) — plots a scatter plot with x-axis values against y-axis values
#
# axes() — adds an axes to the current figure
#
# set_xlabel(“string”) — axes level method used to set the x-label of the plot specified as a string
#
# set_ylabel(“string”) — axes level method used to set the y-label of the plot specified as a string
#
# scatter3D(x-axis values, y-axis values) — plots a three-dimensional scatter plot with x-axis values against y-axis values
#
# plot3D(x-axis values, y-axis values) — plots a three-dimensional line graph with x-axis values against y-axis values
